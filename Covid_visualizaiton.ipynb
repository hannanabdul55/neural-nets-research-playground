# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib as mpl
from os import path
from datetime import date


IPython_default = plt.rcParams.copy()
print(mpl.style.available)
def set_default():
    plt.rcParams.update(IPython_default);
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'tableau-colorblind10', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %%
# mpl.style.use('seaborn-whitegrid')
mpl.style.reload_library()
mpl.style.use('ggplot')
# mpl.style.use('ggplot')

# %% [markdown]
# # COVID-19 India data visualizations

# %%
refresh = False
path_ob = './%s'%('covid-testing-all-observations.csv')
path_test = './%s'% ('owid-covid-data.csv')
if not path.exists(path_ob) or refresh:
    # !rm -f ./covid-testing-all-observations.csv
    # !wget  https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/testing/covid-testing-all-observations.csv

if not path.exists(path_test) or refresh:
    # !rm -f ./owid-covid-data.csv
    # !wget https://covid.ourworldindata.org/data/owid-covid-data.csv

# %%
testing = pd.read_csv(path_test)
obs = pd.read_csv(path_ob)
display(testing.groupby('location').get_group('India'))
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 7366      IND    India  2019-12-31            0          0             0
# 7367      IND    India  2020-01-01            0          0             0
# 7368      IND    India  2020-01-02            0          0             0
# 7369      IND    India  2020-01-03            0          0             0
# 7370      IND    India  2020-01-04            0          0             0
# ...       ...      ...         ...          ...        ...           ...
# 7496      IND    India  2020-05-10        62939       3277          2109
# 7497      IND    India  2020-05-11        67152       4213          2206
# 7498      IND    India  2020-05-12        70756       3604          2293
# 7499      IND    India  2020-05-13        74281       3525          2415
# 7500      IND    India  2020-05-14        78003       3722          2549
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 7366           0                    0.000                  0.000
# 7367           0                    0.000                  0.000
# 7368           0                    0.000                  0.000
# 7369           0                    0.000                  0.000
# 7370           0                    0.000                  0.000
# ...          ...                      ...                    ...
# 7496         128                   45.608                  2.375
# 7497          97                   48.661                  3.053
# 7498          87                   51.272                  2.612
# 7499         122                   53.827                  2.554
# 7500         134                   56.524                  2.697
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 7366                     0.000  ...          5.989          3.414
# 7367                     0.000  ...          5.989          3.414
# 7368                     0.000  ...          5.989          3.414
# 7369                     0.000  ...          5.989          3.414
# 7370                     0.000  ...          5.989          3.414
# ...                        ...  ...            ...            ...
# 7496                     1.528  ...          5.989          3.414
# 7497                     1.599  ...          5.989          3.414
# 7498                     1.662  ...          5.989          3.414
# 7499                     1.750  ...          5.989          3.414
# 7500                     1.847  ...          5.989          3.414
#
#       gdp_per_capita  extreme_poverty  cvd_death_rate diabetes_prevalence  \
# 7366        6426.674             21.2          282.28               10.39
# 7367        6426.674             21.2          282.28               10.39
# 7368        6426.674             21.2          282.28               10.39
# 7369        6426.674             21.2          282.28               10.39
# 7370        6426.674             21.2          282.28               10.39
# ...              ...              ...             ...                 ...
# 7496        6426.674             21.2          282.28               10.39
# 7497        6426.674             21.2          282.28               10.39
# 7498        6426.674             21.2          282.28               10.39
# 7499        6426.674             21.2          282.28               10.39
# 7500        6426.674             21.2          282.28               10.39
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 7366             1.9          20.6                   59.55
# 7367             1.9          20.6                   59.55
# 7368             1.9          20.6                   59.55
# 7369             1.9          20.6                   59.55
# 7370             1.9          20.6                   59.55
# ...              ...           ...                     ...
# 7496             1.9          20.6                   59.55
# 7497             1.9          20.6                   59.55
# 7498             1.9          20.6                   59.55
# 7499             1.9          20.6                   59.55
# 7500             1.9          20.6                   59.55
#
#       hospital_beds_per_100k
# 7366                    0.53
# 7367                    0.53
# 7368                    0.53
# 7369                    0.53
# 7370                    0.53
# ...                      ...
# 7496                    0.53
# 7497                    0.53
# 7498                    0.53
# 7499                    0.53
# 7500                    0.53
#
# [135 rows x 29 columns]

# %%
display(obs)
# Out:
#                            Entity ISO code        Date  \
# 0     Argentina - tests performed      ARG  2020-04-08
# 1     Argentina - tests performed      ARG  2020-04-09
# 2     Argentina - tests performed      ARG  2020-04-10
# 3     Argentina - tests performed      ARG  2020-04-11
# 4     Argentina - tests performed      ARG  2020-04-13
# ...                           ...      ...         ...
# 4704   Zimbabwe - tests performed      ZWE  2020-05-09
# 4705   Zimbabwe - tests performed      ZWE  2020-05-10
# 4706   Zimbabwe - tests performed      ZWE  2020-05-11
# 4707   Zimbabwe - tests performed      ZWE  2020-05-12
# 4708   Zimbabwe - tests performed      ZWE  2020-05-13
#
#                                              Source URL  \
# 0     https://www.argentina.gob.ar/sites/default/fil...
# 1     https://www.argentina.gob.ar/sites/default/fil...
# 2     https://www.argentina.gob.ar/sites/default/fil...
# 3     https://www.argentina.gob.ar/sites/default/fil...
# 4     https://www.argentina.gob.ar/sites/default/fil...
# ...                                                 ...
# 4704  https://twitter.com/MoHCCZim/status/1259335009...
# 4705  https://twitter.com/MoHCCZim/status/1259679483...
# 4706  https://twitter.com/MoHCCZim/status/1260066306...
# 4707  https://twitter.com/MoHCCZim/status/1260433719...
# 4708  https://twitter.com/MoHCCZim/status/1260794875...
#
#                                     Source label Notes  Cumulative total  \
# 0                        Government of Argentina   NaN             13330
# 1                        Government of Argentina   NaN             14850
# 2                        Government of Argentina   NaN             16379
# 3                        Government of Argentina   NaN             18027
# 4                        Government of Argentina   NaN             19758
# ...                                          ...   ...               ...
# 4704  Zimbabwe Ministry of Health and Child Care   NaN              9593
# 4705  Zimbabwe Ministry of Health and Child Care   NaN              9872
# 4706  Zimbabwe Ministry of Health and Child Care   NaN             10598
# 4707  Zimbabwe Ministry of Health and Child Care   NaN             11058
# 4708  Zimbabwe Ministry of Health and Child Care   NaN             11191
#
#       Daily change in cumulative total  Cumulative total per thousand  \
# 0                                  NaN                          0.295
# 1                               1520.0                          0.329
# 2                               1529.0                          0.362
# 3                               1648.0                          0.399
# 4                                  NaN                          0.437
# ...                                ...                            ...
# 4704                             852.0                          0.645
# 4705                             279.0                          0.664
# 4706                             726.0                          0.713
# 4707                             460.0                          0.744
# 4708                               NaN                          0.753
#
#       Daily change in cumulative total per thousand  \
# 0                                               NaN
# 1                                             0.034
# 2                                             0.034
# 3                                             0.036
# 4                                               NaN
# ...                                             ...
# 4704                                          0.057
# 4705                                          0.019
# 4706                                          0.049
# 4707                                          0.031
# 4708                                          0.009
#
#       3-day rolling mean daily change  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                            1565.667
# 4                                 NaN
# ...                               ...
# 4704                          595.000
# 4705                          577.000
# 4706                          619.000
# 4707                          488.333
# 4708                              NaN
#
#       3-day rolling mean daily change per thousand  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                            0.035
# 4                                              NaN
# ...                                            ...
# 4704                                         0.040
# 4705                                         0.039
# 4706                                         0.042
# 4707                                         0.033
# 4708                                         0.030
#
#       7-day rolling mean daily change  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 4704                              NaN
# 4705                              NaN
# 4706                              NaN
# 4707                              NaN
# 4708                              NaN
#
#       7-day rolling mean daily change per thousand
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 4704                                           NaN
# 4705                                           NaN
# 4706                                           NaN
# 4707                                           NaN
# 4708                                         0.032
#
# [4709 rows x 14 columns]

# %%
a = testing.groupby('location').get_group('India')
fig = plt.figure(figsize=(20,15))
cols = np.array(['new_cases', 'new_deaths', 'total_deaths'])
ax = a.plot(x='date', y=cols)
ax.set_title('India covid progression')
# display(obs)
# Out:
# Text(0.5, 1.0, 'India covid progression')

# %%
a = testing.groupby('location').get_group('India')
fig = plt.figure(figsize=(20,15))
tot_cols = np.array(['total_cases', 'total_deaths'])
ax = a.plot(x='date', y=tot_cols)
ax.set_title('India covid progression')
# Out:
# Text(0.5, 1.0, 'India covid progression')

# %% [markdown]
# # United States State-wise covid visualization

# %%
# using OWID data
us_c = np.array(['new_cases', 'new_deaths'])
usa = testing.groupby('location').get_group('United States')
usa.plot(x='date', y=us_c)
display(usa)
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 16183      USA  United States  2019-12-31            0          0
# 16184      USA  United States  2020-01-01            0          0
# 16185      USA  United States  2020-01-02            0          0
# 16186      USA  United States  2020-01-03            0          0
# 16187      USA  United States  2020-01-04            0          0
# ...        ...            ...         ...          ...        ...
# 16314      USA  United States  2020-05-10      1309541      25612
# 16315      USA  United States  2020-05-11      1329799      20258
# 16316      USA  United States  2020-05-12      1347916      18117
# 16317      USA  United States  2020-05-13      1369964      22048
# 16318      USA  United States  2020-05-14      1390746      20782
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 16183             0           0                    0.000
# 16184             0           0                    0.000
# 16185             0           0                    0.000
# 16186             0           0                    0.000
# 16187             0           0                    0.000
# ...             ...         ...                      ...
# 16314         78794        1614                 3956.286
# 16315         79528         734                 4017.488
# 16316         80684        1156                 4072.221
# 16317         82387        1703                 4138.831
# 16318         84133        1746                 4201.616
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 16183                  0.000                     0.000  ...         15.413
# 16184                  0.000                     0.000  ...         15.413
# 16185                  0.000                     0.000  ...         15.413
# 16186                  0.000                     0.000  ...         15.413
# 16187                  0.000                     0.000  ...         15.413
# ...                      ...                       ...  ...            ...
# 16314                 77.377                   238.046  ...         15.413
# 16315                 61.202                   240.264  ...         15.413
# 16316                 54.734                   243.756  ...         15.413
# 16317                 66.610                   248.901  ...         15.413
# 16318                 62.785                   254.176  ...         15.413
#
#        aged_70_older  gdp_per_capita  extreme_poverty  cvd_death_rate  \
# 16183          9.732       54225.446              1.2         151.089
# 16184          9.732       54225.446              1.2         151.089
# 16185          9.732       54225.446              1.2         151.089
# 16186          9.732       54225.446              1.2         151.089
# 16187          9.732       54225.446              1.2         151.089
# ...              ...             ...              ...             ...
# 16314          9.732       54225.446              1.2         151.089
# 16315          9.732       54225.446              1.2         151.089
# 16316          9.732       54225.446              1.2         151.089
# 16317          9.732       54225.446              1.2         151.089
# 16318          9.732       54225.446              1.2         151.089
#
#       diabetes_prevalence  female_smokers  male_smokers  \
# 16183               10.79            19.1          24.6
# 16184               10.79            19.1          24.6
# 16185               10.79            19.1          24.6
# 16186               10.79            19.1          24.6
# 16187               10.79            19.1          24.6
# ...                   ...             ...           ...
# 16314               10.79            19.1          24.6
# 16315               10.79            19.1          24.6
# 16316               10.79            19.1          24.6
# 16317               10.79            19.1          24.6
# 16318               10.79            19.1          24.6
#
#        handwashing_facilities  hospital_beds_per_100k
# 16183                     NaN                    2.77
# 16184                     NaN                    2.77
# 16185                     NaN                    2.77
# 16186                     NaN                    2.77
# 16187                     NaN                    2.77
# ...                       ...                     ...
# 16314                     NaN                    2.77
# 16315                     NaN                    2.77
# 16316                     NaN                    2.77
# 16317                     NaN                    2.77
# 16318                     NaN                    2.77
#
# [136 rows x 29 columns]

# %% [markdown]
# # NYTimes database

# %%
def convert_col(df, col, datatype):
    df[col] = df[col].astype(datatype)
    pass

def get_state_cd(df_state, state):
    return df_state.loc[state,['cases','deaths']]

# %%
usa = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us.csv', parse_dates=['date'], index_col='date',infer_datetime_format=True)
usa_state = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv', parse_dates=['date'],index_col=['state','date'], infer_datetime_format=True)
usa_c = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv', parse_dates=['date'], infer_datetime_format=True)
# convert_col(usa, 'date', 'datetime64[ns]')
# convert_col(usa_state, 'date', 'datetime64[ns]')
# convert_col(usa_c, 'date', 'datetime64[ns]')

# usa_state['date'] =usa_state['date'].astype('datetime64[ns]')
# usa_state['date'] =usa_state['date'].astype('datetime64[ns]')
# usa_state['date'] =usa_state['date'].astype('datetime64[ns]')
# print('US')
# usa.info()
# print('US State-wise')
usa_state.info()
# print('US County-wise')
# usa_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 3974 entries, ('Washington', Timestamp('2020-01-21 00:00:00')) to ('Wyoming', Timestamp('2020-05-13 00:00:00'))
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fips    3974 non-null   int64
#  1   cases   3974 non-null   int64
#  2   deaths  3974 non-null   int64
# dtypes: int64(3)
# memory usage: 102.3+ KB

# %%
cali = usa_state.loc['New York',['cases','deaths']]
# display(cali)
# cali[usa.index[0]] = 0
# cali.loc[usa.index[0], :] = [cali['fips'][0], 0, 0]
cali = cali.reindex(usa.index, method='ffill').fillna(0)
usa_cd = usa[['cases', 'deaths']]
delta = (cali / (usa_cd - cali))
ax = delta.iloc[-30:, :].plot()
# plt.yscale('log')
# usa[['cases', 'deaths']].plot()
# plt.yscale('log')
# plt.gca()
# display(cali)

# %%
cali = usa_state.loc['Texas',['cases','deaths']]
# display(cali)
# cali[usa.index[0]] = 0
# cali.loc[usa.index[0], :] = [cali['fips'][0], 0, 0]
cali = cali.reindex(usa.index, method='ffill').fillna(0)
usa_cd = usa[['cases', 'deaths']]
delta = (cali / (usa_cd - cali))
ax = delta.iloc[-30:, :].plot()

# %%
# cali = usa.loc['Texas',['cases','deaths']]
# display(cali)
# cali[usa.index[0]] = 0
# cali.loc[usa.index[0], :] = [cali['fips'][0], 0, 0]
# cali = cali.reindex(usa.index, method='ffill').fillna(0)
usa[['cases', 'deaths']].plot()
# delta = (cali / (usa_cd - cali))
# ax = delta.iloc[-30:, :].plot()

# %% [markdown]
# ## Get Neighbouring states

# %%
from bs4 import BeautifulSoup
import urllib.request
import requests

# %%
def get_html_text(url_p):
    print('Reading URL: %s'%(url_p))
    html_t = urllib.request.urlopen(url_p).read()
    soup_t = BeautifulSoup(html_t)
    # kill all script and style elements
    for script in soup_t(["script", "style", 'aside', 'head']):
        script.extract()    # rip it out
    return soup_t.body.main

def get_soup(url_p):
    html_t = urllib.request.urlopen(url_p).read()
    soup_t = BeautifulSoup(html_t)
    # kill all script and style elements
    for script in soup_t(["script", "style", 'aside', 'head']):
        script.extract()    # rip it out
    return soup_t
def get_soup_s(url_p):
    soup_t = BeautifulSoup(url_p)
    # kill all script and style elements
    for script in soup_t(["script", "style", 'aside', 'head']):
        script.extract()    # rip it out
    return soup_t

# r = requests.get(url)
# print(r)

# %%
url = 'https://state.1keydata.com/bordering-states-list.php'
s = get_soup_s(open('./url.html', 'r').read())
tab = s.find("table", {'class': 'content4'})
display(tab)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-7a0bdc0b0d49> in <module>
#       1 url = 'https://state.1keydata.com/bordering-states-list.php'
# ----> 2 s = get_soup_s(open('./url.html', 'r').read())
#       3 tab = s.find("table", {'class': 'content4'})
#       4 display(tab)
#
# FileNotFoundError: [Errno 2] No such file or directory: './url.html'

# %%
ents = tab.find_all('tr')[1:]
res = {}
for e in ents:
    s, nbr = e.find_all('td')
    res[s.text] = list(map(str.strip, nbr.text.split(',')))
print(res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-673ea1577cf3> in <module>
# ----> 1 ents = tab.find_all('tr')[1:]
#       2 res = {}
#       3 for e in ents:
#       4     s, nbr = e.find_all('td')
#       5     res[s.text] = list(map(str.strip, nbr.text.split(',')))
#
# NameError: name 'tab' is not defined

# %%
import json
nbrs = json.loads(open('./states.json', 'r').read())

# %%
mobility = pd.read_csv('./mobility.csv',parse_dates=['date'], infer_datetime_format=True)

# %%
mobility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335463 entries, 0 to 335462
# Data columns (total 11 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   country_region_code                                 335463 non-null  object
#  1   country_region                                      335463 non-null  object
#  2   sub_region_1                                        324243 non-null  object
#  3   sub_region_2                                        224707 non-null  object
#  4   date                                                335463 non-null  datetime64[ns]
#  5   retail_and_recreation_percent_change_from_baseline  335463 non-null  float64
#  6   grocery_and_pharmacy_percent_change_from_baseline   335463 non-null  float64
#  7   parks_percent_change_from_baseline                  335463 non-null  float64
#  8   transit_stations_percent_change_from_baseline       335463 non-null  float64
#  9   workplaces_percent_change_from_baseline             335463 non-null  float64
#  10  residential_percent_change_from_baseline            335463 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(4)
# memory usage: 28.2+ MB

# %%
values = {'retail_and_recreation_percent_change_from_baseline':0.0,
         'grocery_and_pharmacy_percent_change_from_baseline':0.0,
         'parks_percent_change_from_baseline':0.0,
         'transit_stations_percent_change_from_baseline':0.0,
         'workplaces_percent_change_from_baseline':0.0,
         'residential_percent_change_from_baseline':0.0, 
         'country_region_code':'NA'}
mobility.fillna(values, inplace=True)

# %%
usa_m = mobility.groupby('country_region').get_group('United States')

# %%
# mobility['country_region_code'] = mobility['country_region_code'].mask(pd.isna,'NA')
display()
# Out:
#        country_region_code country_region sub_region_1 sub_region_2 date  \
# 0                       NA             NA           NA           NA   NA
# 1                       NA             NA           NA           NA   NA
# 2                       NA             NA           NA           NA   NA
# 3                       NA             NA           NA           NA   NA
# 4                       NA             NA           NA           NA   NA
# ...                    ...            ...          ...          ...  ...
# 335458                  NA             NA           NA           NA   NA
# 335459                  NA             NA           NA           NA   NA
# 335460                  NA             NA           NA           NA   NA
# 335461                  NA             NA           NA           NA   NA
# 335462                  NA             NA           NA           NA   NA
#
#        retail_and_recreation_percent_change_from_baseline  \
# 0                                                      NA
# 1                                                      NA
# 2                                                      NA
# 3                                                      NA
# 4                                                      NA
# ...                                                   ...
# 335458                                                 NA
# 335459                                                 NA
# 335460                                                 NA
# 335461                                                 NA
# 335462                                                 NA
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                     NA
# 1                                                     NA
# 2                                                     NA
# 3                                                     NA
# 4                                                     NA
# ...                                                  ...
# 335458                                                NA
# 335459                                                NA
# 335460                                                NA
# 335461                                                NA
# 335462                                                NA
#
#        parks_percent_change_from_baseline  \
# 0                                      NA
# 1                                      NA
# 2                                      NA
# 3                                      NA
# 4                                      NA
# ...                                   ...
# 335458                                 NA
# 335459                                 NA
# 335460                                 NA
# 335461                                 NA
# 335462                                 NA
#
#        transit_stations_percent_change_from_baseline  \
# 0                                                 NA
# 1                                                 NA
# 2                                                 NA
# 3                                                 NA
# 4                                                 NA
# ...                                              ...
# 335458                                            NA
# 335459                                            NA
# 335460                                            NA
# 335461                                            NA
# 335462                                            NA
#
#        workplaces_percent_change_from_baseline  \
# 0                                           NA
# 1                                           NA
# 2                                           NA
# 3                                           NA
# 4                                           NA
# ...                                        ...
# 335458                                      NA
# 335459                                      NA
# 335460                                      NA
# 335461                                      NA
# 335462                                      NA
#
#        residential_percent_change_from_baseline
# 0                                            NA
# 1                                            NA
# 2                                            NA
# 3                                            NA
# 4                                            NA
# ...                                         ...
# 335458                                       NA
# 335459                                       NA
# 335460                                       NA
# 335461                                       NA
# 335462                                       NA
#
# [335463 rows x 11 columns]

# %%
usa
# Out:
#               cases  deaths
# date
# 2020-01-21        1       0
# 2020-01-22        1       0
# 2020-01-23        1       0
# 2020-01-24        2       0
# 2020-01-25        3       0
# ...             ...     ...
# 2020-05-09  1316443   78762
# 2020-05-10  1336754   79693
# 2020-05-11  1354350   80682
# 2020-05-12  1376642   82339
# 2020-05-13  1397784   84109
#
# [114 rows x 2 columns]
